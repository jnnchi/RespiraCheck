# %%
from data_processing.audio_augment import DataAugmentProcessor

# %%
tester = DataAugmentProcessor("/ml/data/cough_data/original_data/negative/087749f6-e253-464f-b576-e85f6ed62cae.wav")

# %%
tester.plot_compare()
