# %% [markdown]
# # CNN-LSTM Hybrid
#
# Note: All folders have been saved in runtime or Google Drive

# %%
# Importing Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install noisereduce
# !pip install pydub
# !pip install torchmetrics

import torchvision.models as models
import os
from PIL import Image
import numpy as np
import collections
from datetime import datetime
import time
import librosa
import sys
import matplotlib.pyplot as plt
import pandas as pd
import io
from tqdm import tqdm
import librosa
import librosa.display
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import soundfile as sf
from scipy.signal import butter, lfilter
import json
import librosa.feature
from contextlib import nullcontext
import torch
import torch.nn as nn
from torch.utils.data import random_split, DataLoader, TensorDataset, WeightedRandomSampler
from torchvision import transforms
import noisereduce as nr
from pydub import AudioSegment, silence
from pydub.silence import detect_nonsilent
import torchmetrics
import torch.optim
import torch.optim as opt
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.14.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting torchmetrics
#   Downloading torchmetrics-1.7.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.14.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.7.0-py3-none-any.whl (960 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.9/960.9 kB 25.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.2-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 47.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.14.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchmetrics-1.7.0

# %%
# !unzip '/content/spectrogram_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: spectrogram_dataset/negative/a5fa6e70-f8bb-4b84-93fa-c153b03514f5.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a5fa6e70-f8bb-4b84-93fa-c153b03514f5.png
#   inflating: spectrogram_dataset/negative/e39a3d8b-8143-40e3-a991-d7c7a8aef8b8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e39a3d8b-8143-40e3-a991-d7c7a8aef8b8.png
#   inflating: spectrogram_dataset/negative/c3542347-5c21-4892-819c-c30853e877a1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c3542347-5c21-4892-819c-c30853e877a1.png
#   inflating: spectrogram_dataset/negative/Ahv0311uRogDaFFI4X22nzsNVvK2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._Ahv0311uRogDaFFI4X22nzsNVvK2_1.png
#   inflating: spectrogram_dataset/negative/c7d13aae-05a9-415b-b0e2-045667d0a5af.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c7d13aae-05a9-415b-b0e2-045667d0a5af.png
#   inflating: spectrogram_dataset/negative/e7006acb-7872-4437-bd95-bbd73113bee0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e7006acb-7872-4437-bd95-bbd73113bee0.png
#   inflating: spectrogram_dataset/negative/de73fa2b-ff9b-483a-a3f7-aefe050da9a7.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._de73fa2b-ff9b-483a-a3f7-aefe050da9a7.png
#   inflating: spectrogram_dataset/negative/cV9R1idnuDfxw4jmzpA7Sj94O5J3_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cV9R1idnuDfxw4jmzpA7Sj94O5J3_1.png
#   inflating: spectrogram_dataset/negative/eab053b6-302e-46b9-8891-9587691c0dcc.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._eab053b6-302e-46b9-8891-9587691c0dcc.png
#   inflating: spectrogram_dataset/negative/e3dab96c-1edc-4908-a784-2ba3a54d131f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e3dab96c-1edc-4908-a784-2ba3a54d131f.png
#   inflating: spectrogram_dataset/negative/a6c40bc9-5866-45bf-b17a-680e2b3a4773.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a6c40bc9-5866-45bf-b17a-680e2b3a4773.png
#   inflating: spectrogram_dataset/negative/ef0185ed-6b9b-4c12-b1a6-800ed89b4413.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ef0185ed-6b9b-4c12-b1a6-800ed89b4413.png
#   inflating: spectrogram_dataset/negative/e642e043-470e-4515-a497-0a98e3f1e654.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e642e043-470e-4515-a497-0a98e3f1e654.png
#   inflating: spectrogram_dataset/negative/f18cf09c-abaf-472b-ae3c-8b59c9c6b13d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f18cf09c-abaf-472b-ae3c-8b59c9c6b13d.png
#   inflating: spectrogram_dataset/negative/fb2c5d95-eb2e-410c-a226-dbb061b88746.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fb2c5d95-eb2e-410c-a226-dbb061b88746.png
#   inflating: spectrogram_dataset/negative/b048d658-0973-47ce-b1fd-4cedcda58371.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b048d658-0973-47ce-b1fd-4cedcda58371.png
#   inflating: spectrogram_dataset/negative/c7ffb5ad-fe2e-4ff7-b110-c9ad8ca50a95.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c7ffb5ad-fe2e-4ff7-b110-c9ad8ca50a95.png
#   inflating: spectrogram_dataset/negative/D8gFH60PUrfFJEG2wXhvPCeTRCq1_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._D8gFH60PUrfFJEG2wXhvPCeTRCq1_1.png
#   inflating: spectrogram_dataset/negative/c8834a06-01f6-4338-a244-f59d0413a5d1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c8834a06-01f6-4338-a244-f59d0413a5d1.png
#   inflating: spectrogram_dataset/negative/a553ed8e-9e49-43f1-b99e-db396dd3121e.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a553ed8e-9e49-43f1-b99e-db396dd3121e.png
#   inflating: spectrogram_dataset/negative/addd9a82-eafe-4212-9310-96f52ac2b27b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._addd9a82-eafe-4212-9310-96f52ac2b27b.png
#   inflating: spectrogram_dataset/negative/fe64652d-1065-4ffd-941a-cc2852806a7f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fe64652d-1065-4ffd-941a-cc2852806a7f.png
#   inflating: spectrogram_dataset/negative/ed9a9016-3480-4307-ade6-b116c2bb06cf.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ed9a9016-3480-4307-ade6-b116c2bb06cf.png
#   inflating: spectrogram_dataset/negative/b9aa3e70-8e36-4645-ae62-ec44066febdb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b9aa3e70-8e36-4645-ae62-ec44066febdb.png
#   inflating: spectrogram_dataset/negative/c85b3e99-29fa-4331-a5c3-f7258baec02b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c85b3e99-29fa-4331-a5c3-f7258baec02b.png
#   inflating: spectrogram_dataset/negative/f55ff264-963d-4cf0-a563-3a7dbf4d9b39.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f55ff264-963d-4cf0-a563-3a7dbf4d9b39.png
#   inflating: spectrogram_dataset/negative/d474b19c-bc88-4c58-8cfc-5bca2308077c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d474b19c-bc88-4c58-8cfc-5bca2308077c.png
#   inflating: spectrogram_dataset/negative/d13b0fec-948e-4265-8458-102e14fd374d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d13b0fec-948e-4265-8458-102e14fd374d.png
#   inflating: spectrogram_dataset/negative/d640214b-314b-4fb4-a919-935ecd4a3710.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d640214b-314b-4fb4-a919-935ecd4a3710.png
#   inflating: spectrogram_dataset/negative/b2d7caf4-2a5f-4c6d-8d73-f012179e7831.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b2d7caf4-2a5f-4c6d-8d73-f012179e7831.png
#   inflating: spectrogram_dataset/negative/f1128452-2715-497a-987e-e6d915fab41b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f1128452-2715-497a-987e-e6d915fab41b.png
#   inflating: spectrogram_dataset/negative/bjA2KpSxneNskrLBeqi4bqoTDQl2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bjA2KpSxneNskrLBeqi4bqoTDQl2_1.png
#   inflating: spectrogram_dataset/negative/ab808e5c-e74b-49fd-a52c-47b01e7d8cf6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ab808e5c-e74b-49fd-a52c-47b01e7d8cf6.png
#   inflating: spectrogram_dataset/negative/d6448211-cb29-4e8a-b384-79c8160f8144.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d6448211-cb29-4e8a-b384-79c8160f8144.png
#   inflating: spectrogram_dataset/negative/e23f63e2-b92f-4548-b4e5-360828546d4b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e23f63e2-b92f-4548-b4e5-360828546d4b.png
#   inflating: spectrogram_dataset/negative/ded8f478-50cf-45ec-ac6a-3922fb1ecb1a.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ded8f478-50cf-45ec-ac6a-3922fb1ecb1a.png
#   inflating: spectrogram_dataset/negative/a77fd243-576e-4c09-a07f-d7993ec40bfc.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a77fd243-576e-4c09-a07f-d7993ec40bfc.png
#   inflating: spectrogram_dataset/negative/e6418b92-7919-496f-9018-477fe37d0558.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e6418b92-7919-496f-9018-477fe37d0558.png
#   inflating: spectrogram_dataset/negative/f5afa857-e4c0-4f97-afdf-ee9ecd3a099c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f5afa857-e4c0-4f97-afdf-ee9ecd3a099c.png
#   inflating: spectrogram_dataset/negative/b60cbc08-a1ad-44af-b0d2-3ee5e09acf14.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b60cbc08-a1ad-44af-b0d2-3ee5e09acf14.png
#   inflating: spectrogram_dataset/negative/f46e2733-fa94-4e29-8144-435333b7eba9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f46e2733-fa94-4e29-8144-435333b7eba9.png
#   inflating: spectrogram_dataset/negative/ce98cf4f-aa0f-466f-b2c1-b64c5322fab2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ce98cf4f-aa0f-466f-b2c1-b64c5322fab2.png
#   inflating: spectrogram_dataset/negative/cd3969ba-1b55-441c-88ec-669631365532.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cd3969ba-1b55-441c-88ec-669631365532.png
#   inflating: spectrogram_dataset/negative/fba9f10e-22c6-442c-99a8-2c10791a5708.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fba9f10e-22c6-442c-99a8-2c10791a5708.png
#   inflating: spectrogram_dataset/negative/ea1a1ee2-eed8-4ead-b8e1-35f0bc8329f0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ea1a1ee2-eed8-4ead-b8e1-35f0bc8329f0.png
#   inflating: spectrogram_dataset/negative/e0ddb4b7-e124-491f-b049-04ab50f51b01.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e0ddb4b7-e124-491f-b049-04ab50f51b01.png
#   inflating: spectrogram_dataset/negative/bdc62dde-32d2-45a6-8fe3-832cc59cdeb3.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bdc62dde-32d2-45a6-8fe3-832cc59cdeb3.png
#   inflating: spectrogram_dataset/negative/e3eba4af-a0b5-40e7-beb3-a6020b72f050.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e3eba4af-a0b5-40e7-beb3-a6020b72f050.png
#   inflating: spectrogram_dataset/negative/e30a9dd3-1345-4f38-80ba-22238e78f0c8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e30a9dd3-1345-4f38-80ba-22238e78f0c8.png
#   inflating: spectrogram_dataset/negative/d2150c82-49c0-4fb9-9f04-7db44aa8919f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d2150c82-49c0-4fb9-9f04-7db44aa8919f.png
#   inflating: spectrogram_dataset/negative/Eoyf44CUffgVCPPjJJkopEyAO7k2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._Eoyf44CUffgVCPPjJJkopEyAO7k2_1.png
#   inflating: spectrogram_dataset/negative/b90768d0-021a-4d48-b713-038ba1fab0fc.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b90768d0-021a-4d48-b713-038ba1fab0fc.png
#   inflating: spectrogram_dataset/negative/db64ee39-b025-462e-a7f8-3ac27b636920.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._db64ee39-b025-462e-a7f8-3ac27b636920.png
#   inflating: spectrogram_dataset/negative/bff11751-e143-4e5a-b70f-e4b748a6bf33.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bff11751-e143-4e5a-b70f-e4b748a6bf33.png
#   inflating: spectrogram_dataset/negative/abe31790-0076-4e40-a200-6203543b67bd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._abe31790-0076-4e40-a200-6203543b67bd.png
#   inflating: spectrogram_dataset/negative/a830dbe5-5e1d-4aaf-a18f-fd08e84b02a4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a830dbe5-5e1d-4aaf-a18f-fd08e84b02a4.png
#   inflating: spectrogram_dataset/negative/f9bc52a5-b269-40c7-b372-c1814084b7f0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f9bc52a5-b269-40c7-b372-c1814084b7f0.png
#   inflating: spectrogram_dataset/negative/beeb9e16-4d49-401f-8120-c1a98b234f3e.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._beeb9e16-4d49-401f-8120-c1a98b234f3e.png
#   inflating: spectrogram_dataset/negative/d180a2c7-add6-4aad-820d-7fe93ac4e102.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d180a2c7-add6-4aad-820d-7fe93ac4e102.png
#   inflating: spectrogram_dataset/negative/f101dcbe-4173-426c-a713-7c153d7b28bd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f101dcbe-4173-426c-a713-7c153d7b28bd.png
#   inflating: spectrogram_dataset/negative/bf19088f-e09f-4dc4-af7d-80f43d9cf085.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bf19088f-e09f-4dc4-af7d-80f43d9cf085.png
#   inflating: spectrogram_dataset/negative/c167d6d1-8671-49d5-8d18-a533f6ba7557.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c167d6d1-8671-49d5-8d18-a533f6ba7557.png
#   inflating: spectrogram_dataset/negative/d16b3a71-caa8-45aa-8b42-7d0b7cd4ae98.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d16b3a71-caa8-45aa-8b42-7d0b7cd4ae98.png
#   inflating: spectrogram_dataset/negative/a25b4a6c-8c51-4ce9-b7b5-ed71625e8388.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a25b4a6c-8c51-4ce9-b7b5-ed71625e8388.png
#   inflating: spectrogram_dataset/negative/af955580-9dfe-4045-b718-155078558bc4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._af955580-9dfe-4045-b718-155078558bc4.png
#   inflating: spectrogram_dataset/negative/bdf5b8ef-a953-4f16-860c-9f7bae0b3ef0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bdf5b8ef-a953-4f16-860c-9f7bae0b3ef0.png
#   inflating: spectrogram_dataset/negative/EucWZQ2KbbQ74NhWqnrUEuS7pU53_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._EucWZQ2KbbQ74NhWqnrUEuS7pU53_1.png
#   inflating: spectrogram_dataset/negative/f24eb21f-83a4-4a83-a00b-af6450f51ec8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f24eb21f-83a4-4a83-a00b-af6450f51ec8.png
#   inflating: spectrogram_dataset/negative/b750b4b4-e331-456f-80e0-599629df4394.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b750b4b4-e331-456f-80e0-599629df4394.png
#   inflating: spectrogram_dataset/negative/b625959f-b924-4944-8420-53f708bff2c1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b625959f-b924-4944-8420-53f708bff2c1.png
#   inflating: spectrogram_dataset/negative/f430ebc8-23c5-48cf-91ca-e54f91894f49.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f430ebc8-23c5-48cf-91ca-e54f91894f49.png
#   inflating: spectrogram_dataset/negative/c865661b-f1c3-4994-a669-7a77fe980043.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c865661b-f1c3-4994-a669-7a77fe980043.png
#   inflating: spectrogram_dataset/negative/a7f4eaa2-3010-4dae-97c2-2b3ebf00c9d0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a7f4eaa2-3010-4dae-97c2-2b3ebf00c9d0.png
#   inflating: spectrogram_dataset/negative/fc2836ad-f60a-4f9c-acc7-a138244f1bbd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fc2836ad-f60a-4f9c-acc7-a138244f1bbd.png
#   inflating: spectrogram_dataset/negative/f38c821b-1893-4581-8625-2a70f2db59b0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f38c821b-1893-4581-8625-2a70f2db59b0.png
#   inflating: spectrogram_dataset/negative/b3xN4I45RJb7nxHBRUd6Q6yx3z33_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b3xN4I45RJb7nxHBRUd6Q6yx3z33_1.png
#   inflating: spectrogram_dataset/negative/c1712abb-0a25-46ba-ba5c-9ccf52ce2104.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c1712abb-0a25-46ba-ba5c-9ccf52ce2104.png
#   inflating: spectrogram_dataset/negative/e5a30cc2-c96a-44d0-adf9-f5e9eab0a6e9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e5a30cc2-c96a-44d0-adf9-f5e9eab0a6e9.png
#   inflating: spectrogram_dataset/negative/CjVKAdiAXkdaeNfQ7O9VWBrSpLl2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._CjVKAdiAXkdaeNfQ7O9VWBrSpLl2_1.png
#   inflating: spectrogram_dataset/negative/c4606332-76e8-489b-9ec6-5c87b011927d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c4606332-76e8-489b-9ec6-5c87b011927d.png
#   inflating: spectrogram_dataset/negative/a8082f4c-c1d7-4ee1-8f29-41558c983a79.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a8082f4c-c1d7-4ee1-8f29-41558c983a79.png
#   inflating: spectrogram_dataset/negative/ec388fcd-f4cd-4bf7-968d-d485831c4c64.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ec388fcd-f4cd-4bf7-968d-d485831c4c64.png
#   inflating: spectrogram_dataset/negative/cf79e5f9-badf-4b30-af9f-1b09740272e4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cf79e5f9-badf-4b30-af9f-1b09740272e4.png
#   inflating: spectrogram_dataset/negative/e1dfd5a6-39de-47b9-aad5-2082dfd5fd98.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e1dfd5a6-39de-47b9-aad5-2082dfd5fd98.png
#   inflating: spectrogram_dataset/negative/a67ca13d-dc6a-44b1-a80c-b63de6fc3bc8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a67ca13d-dc6a-44b1-a80c-b63de6fc3bc8.png
#   inflating: spectrogram_dataset/negative/a40decbe-2d61-45f0-862e-6b4060a07161.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a40decbe-2d61-45f0-862e-6b4060a07161.png
#   inflating: spectrogram_dataset/negative/c523afbe-7eaf-4789-8080-3771f4c9b4da.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c523afbe-7eaf-4789-8080-3771f4c9b4da.png
#   inflating: spectrogram_dataset/negative/c93b8c89-08c3-4278-9aee-0ba444be8314.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c93b8c89-08c3-4278-9aee-0ba444be8314.png
#   inflating: spectrogram_dataset/negative/e8a6fe6f-2e87-4884-8377-8c9e98980ef4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e8a6fe6f-2e87-4884-8377-8c9e98980ef4.png
#   inflating: spectrogram_dataset/negative/bd63520f-82c6-4abf-81d2-1d2c60401222.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bd63520f-82c6-4abf-81d2-1d2c60401222.png
#   inflating: spectrogram_dataset/negative/cb608b60-4853-4228-a422-0aefc7dc3803.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cb608b60-4853-4228-a422-0aefc7dc3803.png
#   inflating: spectrogram_dataset/negative/c75f4d9d-6c91-4eb6-b5d9-e0e5bd749c19.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c75f4d9d-6c91-4eb6-b5d9-e0e5bd749c19.png
#   inflating: spectrogram_dataset/negative/f780d9d3-f68d-49c1-914f-c28cc0784759.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f780d9d3-f68d-49c1-914f-c28cc0784759.png
#   inflating: spectrogram_dataset/negative/c8203c30-f4ce-457e-afe5-817af10316ae.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c8203c30-f4ce-457e-afe5-817af10316ae.png
#   inflating: spectrogram_dataset/negative/f753f5cb-96e5-4892-95e8-ce1390f64208.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f753f5cb-96e5-4892-95e8-ce1390f64208.png
#   inflating: spectrogram_dataset/negative/e363e996-6ec4-4aa1-b70a-e57871a2e826.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e363e996-6ec4-4aa1-b70a-e57871a2e826.png
#   inflating: spectrogram_dataset/negative/a9fb93fc-2daa-4d87-a335-422bc485ed9a.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a9fb93fc-2daa-4d87-a335-422bc485ed9a.png
#   inflating: spectrogram_dataset/negative/f2712826-7ccd-462d-9e60-0534a7901470.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f2712826-7ccd-462d-9e60-0534a7901470.png
#   inflating: spectrogram_dataset/negative/ca368145-d84d-4467-b100-0b58c807e09c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ca368145-d84d-4467-b100-0b58c807e09c.png
#   inflating: spectrogram_dataset/negative/c49d491d-2800-4018-a68d-d60d4f16974f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c49d491d-2800-4018-a68d-d60d4f16974f.png
#   inflating: spectrogram_dataset/negative/dae91a69-f637-442f-9641-3a5b1026f370.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._dae91a69-f637-442f-9641-3a5b1026f370.png
#   inflating: spectrogram_dataset/negative/CjVKAdiAXkdaeNfQ7O9VWBrSpLl2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._CjVKAdiAXkdaeNfQ7O9VWBrSpLl2_0.png
#   inflating: spectrogram_dataset/negative/c522332b-13ed-4ce6-8e5f-d41cb611c488.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c522332b-13ed-4ce6-8e5f-d41cb611c488.png
#   inflating: spectrogram_dataset/negative/b3xN4I45RJb7nxHBRUd6Q6yx3z33_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b3xN4I45RJb7nxHBRUd6Q6yx3z33_0.png
#   inflating: spectrogram_dataset/negative/de4c87d3-835e-4223-b14b-4682997c1aa8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._de4c87d3-835e-4223-b14b-4682997c1aa8.png
#   inflating: spectrogram_dataset/negative/f0f780f7-a339-4501-8bee-097873dd1ea7.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f0f780f7-a339-4501-8bee-097873dd1ea7.png
#   inflating: spectrogram_dataset/negative/e188c5fa-1500-42e4-b5f5-b8306e03d298.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e188c5fa-1500-42e4-b5f5-b8306e03d298.png
#   inflating: spectrogram_dataset/negative/dcff89f4-f6a3-4922-860c-66b57c0ae7fd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._dcff89f4-f6a3-4922-860c-66b57c0ae7fd.png
#   inflating: spectrogram_dataset/negative/fbbdc217-c33e-4c96-adaa-394e7853582f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fbbdc217-c33e-4c96-adaa-394e7853582f.png
#   inflating: spectrogram_dataset/negative/bee54bff-7b16-4708-961c-c4f365a80240.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bee54bff-7b16-4708-961c-c4f365a80240.png
#   inflating: spectrogram_dataset/negative/da8804c6-096b-418c-89df-f14642131660.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._da8804c6-096b-418c-89df-f14642131660.png
#   inflating: spectrogram_dataset/negative/da5ae706-3cab-4f61-84d5-0d30be8be7f6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._da5ae706-3cab-4f61-84d5-0d30be8be7f6.png
#   inflating: spectrogram_dataset/negative/b271984e-6538-4ae1-9042-7b6d2fc9cf01.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b271984e-6538-4ae1-9042-7b6d2fc9cf01.png
#   inflating: spectrogram_dataset/negative/EucWZQ2KbbQ74NhWqnrUEuS7pU53_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._EucWZQ2KbbQ74NhWqnrUEuS7pU53_0.png
#   inflating: spectrogram_dataset/negative/d176e889-aea4-47fe-aff4-f24ed2bb335d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d176e889-aea4-47fe-aff4-f24ed2bb335d.png
#   inflating: spectrogram_dataset/negative/aa78ca35-d809-40bc-9cb1-8d7e361cee0e.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._aa78ca35-d809-40bc-9cb1-8d7e361cee0e.png
#   inflating: spectrogram_dataset/negative/cb38c724-2546-4c28-a88b-f28b883fb184.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cb38c724-2546-4c28-a88b-f28b883fb184.png
#   inflating: spectrogram_dataset/negative/fd8cef28-dd97-4f19-9b04-c05a991d2aa0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fd8cef28-dd97-4f19-9b04-c05a991d2aa0.png
#   inflating: spectrogram_dataset/negative/dc4acaaf-ee97-41d5-85af-34298fda2171.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._dc4acaaf-ee97-41d5-85af-34298fda2171.png
#   inflating: spectrogram_dataset/negative/de3d32cf-a1e5-4386-a9af-b5705813df55.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._de3d32cf-a1e5-4386-a9af-b5705813df55.png
#   inflating: spectrogram_dataset/negative/e17922ac-8224-4774-aebb-ea3faff0a479.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e17922ac-8224-4774-aebb-ea3faff0a479.png
#   inflating: spectrogram_dataset/negative/cd5f8c80-ca6f-4689-bc44-2601d0c9cec4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cd5f8c80-ca6f-4689-bc44-2601d0c9cec4.png
#   inflating: spectrogram_dataset/negative/eca32709-8598-4920-9087-86b2240252d4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._eca32709-8598-4920-9087-86b2240252d4.png
#   inflating: spectrogram_dataset/negative/FBdqiwdp4Kc7PpyUkLBM9qMSo2k1_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._FBdqiwdp4Kc7PpyUkLBM9qMSo2k1_1.png
#   inflating: spectrogram_dataset/negative/e6d07d7b-cd63-4f81-8dbd-3ab87104fbf0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e6d07d7b-cd63-4f81-8dbd-3ab87104fbf0.png
#   inflating: spectrogram_dataset/negative/a22099fe-6fb5-47e8-a00e-37cdec4f9d42.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a22099fe-6fb5-47e8-a00e-37cdec4f9d42.png
#   inflating: spectrogram_dataset/negative/a97be390-ed3a-4940-b248-bf7adc433fbb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a97be390-ed3a-4940-b248-bf7adc433fbb.png
#   inflating: spectrogram_dataset/negative/b4a235ed-7a34-4389-9228-20ec446659e0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b4a235ed-7a34-4389-9228-20ec446659e0.png
#   inflating: spectrogram_dataset/negative/Eoyf44CUffgVCPPjJJkopEyAO7k2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._Eoyf44CUffgVCPPjJJkopEyAO7k2_0.png
#   inflating: spectrogram_dataset/negative/efdaa612-fa4f-45d7-9d7b-af8f66d75c37.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._efdaa612-fa4f-45d7-9d7b-af8f66d75c37.png
#   inflating: spectrogram_dataset/negative/d63e9d66-2364-43f0-9dfc-f2767eb1efa8.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d63e9d66-2364-43f0-9dfc-f2767eb1efa8.png
#   inflating: spectrogram_dataset/negative/f21ebca0-35d9-4fd1-83c3-caf1482446da.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f21ebca0-35d9-4fd1-83c3-caf1482446da.png
#   inflating: spectrogram_dataset/negative/acae3594-1a8f-4375-958f-61f37b75021b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._acae3594-1a8f-4375-958f-61f37b75021b.png
#   inflating: spectrogram_dataset/negative/ef9bfd48-ddf2-4ddb-8479-f6d1c3bcfa07.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ef9bfd48-ddf2-4ddb-8479-f6d1c3bcfa07.png
#   inflating: spectrogram_dataset/negative/beca77be-776b-4d24-bb6d-6d70ca178139.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._beca77be-776b-4d24-bb6d-6d70ca178139.png
#   inflating: spectrogram_dataset/negative/b8cb9483-ef13-4d06-aa50-d36d9e0e1cf5.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b8cb9483-ef13-4d06-aa50-d36d9e0e1cf5.png
#   inflating: spectrogram_dataset/negative/a182cac0-f3fe-4ef4-a306-caa6caeb66b6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a182cac0-f3fe-4ef4-a306-caa6caeb66b6.png
#   inflating: spectrogram_dataset/negative/bd38ab63-fa3b-4cea-8a67-544f6e270509.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bd38ab63-fa3b-4cea-8a67-544f6e270509.png
#   inflating: spectrogram_dataset/negative/f62c314d-fe92-492d-ae58-ea092f1b20b3.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f62c314d-fe92-492d-ae58-ea092f1b20b3.png
#   inflating: spectrogram_dataset/negative/d20cf1f5-2bdf-4159-9892-f30a651a561d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d20cf1f5-2bdf-4159-9892-f30a651a561d.png
#   inflating: spectrogram_dataset/negative/d03bc7d5-6c3d-4e75-ab06-3ee662d58171.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d03bc7d5-6c3d-4e75-ab06-3ee662d58171.png
#   inflating: spectrogram_dataset/negative/a130e84a-b279-40ff-849b-824511008ae2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a130e84a-b279-40ff-849b-824511008ae2.png
#   inflating: spectrogram_dataset/negative/bbfddbcb-6f5b-489b-a1a1-837b504f137c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bbfddbcb-6f5b-489b-a1a1-837b504f137c.png
#   inflating: spectrogram_dataset/negative/fa5a2483-3280-4d3b-875b-d78cf8698eef.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fa5a2483-3280-4d3b-875b-d78cf8698eef.png
#   inflating: spectrogram_dataset/negative/c4598675-6bde-474d-8dd3-471493aee3f2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c4598675-6bde-474d-8dd3-471493aee3f2.png
#   inflating: spectrogram_dataset/negative/eb62c8cc-b11a-40c6-b7cc-5049516bbcf9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._eb62c8cc-b11a-40c6-b7cc-5049516bbcf9.png
#   inflating: spectrogram_dataset/negative/c9275d2b-e25b-4c65-8ade-43cf2a738a17.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c9275d2b-e25b-4c65-8ade-43cf2a738a17.png
#   inflating: spectrogram_dataset/negative/f255efb4-c99e-48c5-be11-d71cbf086c06.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f255efb4-c99e-48c5-be11-d71cbf086c06.png
#   inflating: spectrogram_dataset/negative/b167946b-7c00-4143-92bf-5bb7aa84336a.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b167946b-7c00-4143-92bf-5bb7aa84336a.png
#   inflating: spectrogram_dataset/negative/b89891c3-51d2-4c3e-a99a-c4afc075ab40.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b89891c3-51d2-4c3e-a99a-c4afc075ab40.png
#   inflating: spectrogram_dataset/negative/cedae989-c49c-4c60-a8c7-1ca431bf4896.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cedae989-c49c-4c60-a8c7-1ca431bf4896.png
#   inflating: spectrogram_dataset/negative/D8gFH60PUrfFJEG2wXhvPCeTRCq1_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._D8gFH60PUrfFJEG2wXhvPCeTRCq1_0.png
#   inflating: spectrogram_dataset/negative/a5eafeea-b8a5-4bb4-8d28-eba09904d417.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a5eafeea-b8a5-4bb4-8d28-eba09904d417.png
#   inflating: spectrogram_dataset/negative/a20d7bbb-a1e8-40bc-8b03-576facef5197.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a20d7bbb-a1e8-40bc-8b03-576facef5197.png
#   inflating: spectrogram_dataset/negative/cbcb949a-00b7-4dd3-b7cd-f5853642c68b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cbcb949a-00b7-4dd3-b7cd-f5853642c68b.png
#   inflating: spectrogram_dataset/negative/ee4fd5b2-d951-4ba3-9bed-b1269a6c0091.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ee4fd5b2-d951-4ba3-9bed-b1269a6c0091.png
#   inflating: spectrogram_dataset/negative/f013d91b-cc98-44e2-8922-27ba4e50d276.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f013d91b-cc98-44e2-8922-27ba4e50d276.png
#   inflating: spectrogram_dataset/negative/a976e95a-1c9a-43e5-8dcd-b31434093181.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a976e95a-1c9a-43e5-8dcd-b31434093181.png
#   inflating: spectrogram_dataset/negative/c742786e-1fc5-4ec2-988c-f5c31b172715.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c742786e-1fc5-4ec2-988c-f5c31b172715.png
#   inflating: spectrogram_dataset/negative/ee18587f-3c32-4ff2-b550-f3d8aad09742.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ee18587f-3c32-4ff2-b550-f3d8aad09742.png
#   inflating: spectrogram_dataset/negative/d41f1489-4924-45f8-a7b1-db0dedd442fa.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d41f1489-4924-45f8-a7b1-db0dedd442fa.png
#   inflating: spectrogram_dataset/negative/cf689fe6-397b-4e0b-accf-1768449dc2ca.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cf689fe6-397b-4e0b-accf-1768449dc2ca.png
#   inflating: spectrogram_dataset/negative/ec8470e8-e422-4b14-8024-eec1e091deeb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ec8470e8-e422-4b14-8024-eec1e091deeb.png
#   inflating: spectrogram_dataset/negative/cV9R1idnuDfxw4jmzpA7Sj94O5J3_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cV9R1idnuDfxw4jmzpA7Sj94O5J3_0.png
#   inflating: spectrogram_dataset/negative/Ahv0311uRogDaFFI4X22nzsNVvK2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._Ahv0311uRogDaFFI4X22nzsNVvK2_0.png
#   inflating: spectrogram_dataset/negative/d5f3383b-698e-4a44-a34d-1034be9f30b1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d5f3383b-698e-4a44-a34d-1034be9f30b1.png
#   inflating: spectrogram_dataset/negative/ccdf7b8c-3965-443d-b14a-b4d8d7c95e7e.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ccdf7b8c-3965-443d-b14a-b4d8d7c95e7e.png
#   inflating: spectrogram_dataset/negative/b3b23880-5d68-4a1b-8126-3619b1c70c20.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b3b23880-5d68-4a1b-8126-3619b1c70c20.png
#   inflating: spectrogram_dataset/negative/f8188719-121d-45e3-8323-4a20733f52eb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f8188719-121d-45e3-8323-4a20733f52eb.png
#   inflating: spectrogram_dataset/negative/b226b63d-3883-46d5-b949-9cfe0eed579d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b226b63d-3883-46d5-b949-9cfe0eed579d.png
#   inflating: spectrogram_dataset/negative/f7f1f29e-791f-49d5-bd8a-5cb2442b6bdd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f7f1f29e-791f-49d5-bd8a-5cb2442b6bdd.png
#   inflating: spectrogram_dataset/negative/EqDWckxbsETyHUeBLQ8jLtxlhir2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._EqDWckxbsETyHUeBLQ8jLtxlhir2_1.png
#   inflating: spectrogram_dataset/negative/f2c87e3d-6554-4c1b-90bc-9df4fe3d02c2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f2c87e3d-6554-4c1b-90bc-9df4fe3d02c2.png
#   inflating: spectrogram_dataset/negative/dosEoi5rKRVXDZzENH1QpxCfPWu1_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._dosEoi5rKRVXDZzENH1QpxCfPWu1_0.png
#   inflating: spectrogram_dataset/negative/afa96760-d245-4047-81bc-75aedc2359c0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._afa96760-d245-4047-81bc-75aedc2359c0.png
#   inflating: spectrogram_dataset/negative/b0ed5f50-530f-4280-9d71-4ac6b57d0920.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b0ed5f50-530f-4280-9d71-4ac6b57d0920.png
#   inflating: spectrogram_dataset/negative/f7cfc8b1-0477-44e5-b284-40922f204ab4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f7cfc8b1-0477-44e5-b284-40922f204ab4.png
#   inflating: spectrogram_dataset/negative/a27f3a11-9b65-4e99-aa5b-c9866f17f7ec.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a27f3a11-9b65-4e99-aa5b-c9866f17f7ec.png
#   inflating: spectrogram_dataset/negative/f2418053-a721-48e7-a814-11db4d075adb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f2418053-a721-48e7-a814-11db4d075adb.png
#   inflating: spectrogram_dataset/negative/d9c90aa6-53cd-4753-a9e0-f835691b84b4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d9c90aa6-53cd-4753-a9e0-f835691b84b4.png
#   inflating: spectrogram_dataset/negative/ba7ea296-f030-4878-891d-a2bd1526ef8a.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ba7ea296-f030-4878-891d-a2bd1526ef8a.png
#   inflating: spectrogram_dataset/negative/c35ecb21-6cc3-4595-828b-5b0deeeebaff.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c35ecb21-6cc3-4595-828b-5b0deeeebaff.png
#   inflating: spectrogram_dataset/negative/d4b9c48d-575f-4447-bb62-44bbec13d5b4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d4b9c48d-575f-4447-bb62-44bbec13d5b4.png
#   inflating: spectrogram_dataset/negative/a436a7d2-c722-4360-a57a-3daa79bedfcb.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a436a7d2-c722-4360-a57a-3daa79bedfcb.png
#   inflating: spectrogram_dataset/negative/cAqSJ74dT8S95pUV3nj98Pp12cp1_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cAqSJ74dT8S95pUV3nj98Pp12cp1_1.png
#   inflating: spectrogram_dataset/negative/c500d455-d461-47a8-b0b0-ab01a31b7774.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c500d455-d461-47a8-b0b0-ab01a31b7774.png
#   inflating: spectrogram_dataset/negative/e180752d-f220-401b-8274-0da63317c832.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e180752d-f220-401b-8274-0da63317c832.png
#   inflating: spectrogram_dataset/negative/b492f127-ee29-4a55-b479-80e5e3a8a66a.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b492f127-ee29-4a55-b479-80e5e3a8a66a.png
#   inflating: spectrogram_dataset/negative/e7df116c-3ab8-4ed6-a7c1-736e7a9d1f72.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e7df116c-3ab8-4ed6-a7c1-736e7a9d1f72.png
#   inflating: spectrogram_dataset/negative/d9df326c-0236-4322-9105-f734fbc85da3.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d9df326c-0236-4322-9105-f734fbc85da3.png
#   inflating: spectrogram_dataset/negative/elSiVyo2V3USxFXNuExlbh9hrNm1_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._elSiVyo2V3USxFXNuExlbh9hrNm1_0.png
#   inflating: spectrogram_dataset/negative/c91eb79c-31d2-4ba5-9e4e-d95e5d4f5c11.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c91eb79c-31d2-4ba5-9e4e-d95e5d4f5c11.png
#   inflating: spectrogram_dataset/negative/f19eaa2b-040d-4836-9fba-e98b698697f0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f19eaa2b-040d-4836-9fba-e98b698697f0.png
#   inflating: spectrogram_dataset/negative/f9b020ec-7bde-41fe-9f93-f10c06abc08c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f9b020ec-7bde-41fe-9f93-f10c06abc08c.png
#   inflating: spectrogram_dataset/negative/b9d67024-a569-4a37-ad64-ab3cc71e7022.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b9d67024-a569-4a37-ad64-ab3cc71e7022.png
#   inflating: spectrogram_dataset/negative/f3ab745e-7a1c-4fd0-b722-c9104b8c3054.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f3ab745e-7a1c-4fd0-b722-c9104b8c3054.png
#   inflating: spectrogram_dataset/negative/CKQpcw70anZK0rg63buUPt2FlhB3_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._CKQpcw70anZK0rg63buUPt2FlhB3_1.png
#   inflating: spectrogram_dataset/negative/ekXeaNBZYgZvh7mpGGwDQR4Jlwv2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ekXeaNBZYgZvh7mpGGwDQR4Jlwv2_0.png
#   inflating: spectrogram_dataset/negative/a33a2be8-3414-4a1d-ba28-0934d6beb949.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a33a2be8-3414-4a1d-ba28-0934d6beb949.png
#   inflating: spectrogram_dataset/negative/f78b1d7b-ca78-462e-a698-02b2a67940e7.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f78b1d7b-ca78-462e-a698-02b2a67940e7.png
#   inflating: spectrogram_dataset/negative/ade03da1-3b14-4290-a791-de7934e4b4a4.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ade03da1-3b14-4290-a791-de7934e4b4a4.png
#   inflating: spectrogram_dataset/negative/a970a72d-b107-4ec2-b6b5-f28d9998a9d0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a970a72d-b107-4ec2-b6b5-f28d9998a9d0.png
#   inflating: spectrogram_dataset/negative/fa011cb7-cb93-4a12-a1b0-c4e0301321e2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fa011cb7-cb93-4a12-a1b0-c4e0301321e2.png
#   inflating: spectrogram_dataset/negative/ac82e45c-e4b4-4f39-a5b7-4fd872898723.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ac82e45c-e4b4-4f39-a5b7-4fd872898723.png
#   inflating: spectrogram_dataset/negative/f0587ead-efbf-41c1-beb3-faefe195629b.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f0587ead-efbf-41c1-beb3-faefe195629b.png
#   inflating: spectrogram_dataset/negative/c17260b4-c362-4562-ae51-caf3a9628467.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c17260b4-c362-4562-ae51-caf3a9628467.png
#   inflating: spectrogram_dataset/negative/ea80f562-ade9-4b6e-81d4-9d834e786841.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ea80f562-ade9-4b6e-81d4-9d834e786841.png
#   inflating: spectrogram_dataset/negative/e4dbc910-6a8f-4c8e-b482-3197f09707a7.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e4dbc910-6a8f-4c8e-b482-3197f09707a7.png
#   inflating: spectrogram_dataset/negative/clTCcS844yb8ZbQtq8EwQANZ6p22_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._clTCcS844yb8ZbQtq8EwQANZ6p22_0.png
#   inflating: spectrogram_dataset/negative/c9b88c8d-8079-4d02-ba69-514e89dd4a88.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c9b88c8d-8079-4d02-ba69-514e89dd4a88.png
#   inflating: spectrogram_dataset/negative/CpB4mhP3leTMxJdDG3cD3xMN2AI3_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._CpB4mhP3leTMxJdDG3cD3xMN2AI3_0.png
#   inflating: spectrogram_dataset/negative/E8foKQD2BqYfZjFhdhknvaDp3Ot2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._E8foKQD2BqYfZjFhdhknvaDp3Ot2_0.png
#   inflating: spectrogram_dataset/negative/e99af3a7-2de7-4ce7-ae75-ad203bd687e6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e99af3a7-2de7-4ce7-ae75-ad203bd687e6.png
#   inflating: spectrogram_dataset/negative/bc14fb07-2890-4c0a-a793-a8c22d3cd7f9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bc14fb07-2890-4c0a-a793-a8c22d3cd7f9.png
#   inflating: spectrogram_dataset/negative/aNOpaVGqF7PiG5n1ln5B1VJnmCO2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._aNOpaVGqF7PiG5n1ln5B1VJnmCO2_0.png
#   inflating: spectrogram_dataset/negative/e9dc4885-def2-4685-903a-89d953b8288d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e9dc4885-def2-4685-903a-89d953b8288d.png
#   inflating: spectrogram_dataset/negative/da7e7e5a-14a2-4fe6-b8af-f34efc66ec54.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._da7e7e5a-14a2-4fe6-b8af-f34efc66ec54.png
#   inflating: spectrogram_dataset/negative/fac79dc6-06d4-49c6-8edb-da250689b8a5.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fac79dc6-06d4-49c6-8edb-da250689b8a5.png
#   inflating: spectrogram_dataset/negative/cb6134cd-b68f-421f-bc97-fc2420559de6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cb6134cd-b68f-421f-bc97-fc2420559de6.png
#   inflating: spectrogram_dataset/negative/e1838205-c4fb-4a27-8d4f-c3c02f77bab9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e1838205-c4fb-4a27-8d4f-c3c02f77bab9.png
#   inflating: spectrogram_dataset/negative/b39e0801-d103-42d9-8890-48dff12246e6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b39e0801-d103-42d9-8890-48dff12246e6.png
#   inflating: spectrogram_dataset/negative/a19a4b61-f87c-4f5c-a8d9-5d7032c0eba9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a19a4b61-f87c-4f5c-a8d9-5d7032c0eba9.png
#   inflating: spectrogram_dataset/negative/e98950fb-5c07-4d25-ae69-0e4a59b62c7f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e98950fb-5c07-4d25-ae69-0e4a59b62c7f.png
#   inflating: spectrogram_dataset/negative/b7fffb62-78a0-40bb-8558-d5548f4a9b04.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b7fffb62-78a0-40bb-8558-d5548f4a9b04.png
#   inflating: spectrogram_dataset/negative/d6a2d97b-a9a8-4357-b72e-51c863b5ebcd.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d6a2d97b-a9a8-4357-b72e-51c863b5ebcd.png
#   inflating: spectrogram_dataset/negative/a51fcb48-2f3b-4221-9017-9e0cb666fd6d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a51fcb48-2f3b-4221-9017-9e0cb666fd6d.png
#   inflating: spectrogram_dataset/negative/f645f3b2-3a14-4da0-bb98-4a36eb03ed32.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f645f3b2-3a14-4da0-bb98-4a36eb03ed32.png
#   inflating: spectrogram_dataset/negative/cdfaa484-255e-4c90-91a2-8fb6685cfab3.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._cdfaa484-255e-4c90-91a2-8fb6685cfab3.png
#   inflating: spectrogram_dataset/negative/e2bffa5e-1d2d-4e12-8049-1c345adb2778.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e2bffa5e-1d2d-4e12-8049-1c345adb2778.png
#   inflating: spectrogram_dataset/negative/aESHvWgJIodaDacHGg6i3o05bYo2_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._aESHvWgJIodaDacHGg6i3o05bYo2_0.png
#   inflating: spectrogram_dataset/negative/fe54547d-80c3-4e96-83e0-0f480255e811.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._fe54547d-80c3-4e96-83e0-0f480255e811.png
#   inflating: spectrogram_dataset/negative/dce7e6e4-8f03-4062-a005-c9f529ed5e2d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._dce7e6e4-8f03-4062-a005-c9f529ed5e2d.png
#   inflating: spectrogram_dataset/negative/b72d309f-a9b8-4815-86c1-ac642f3dc5f9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b72d309f-a9b8-4815-86c1-ac642f3dc5f9.png
#   inflating: spectrogram_dataset/negative/f27b51ad-ae76-4a6f-9071-4dc3dbdda4ea.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f27b51ad-ae76-4a6f-9071-4dc3dbdda4ea.png
#   inflating: spectrogram_dataset/negative/bb525d5e-edb4-47a9-a97a-66ba8783d626.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bb525d5e-edb4-47a9-a97a-66ba8783d626.png
#   inflating: spectrogram_dataset/negative/abe6b861-2428-415c-8405-dd397ef76de3.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._abe6b861-2428-415c-8405-dd397ef76de3.png
#   inflating: spectrogram_dataset/negative/f587a047-25b5-4991-bfea-22fa573354ff.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f587a047-25b5-4991-bfea-22fa573354ff.png
#   inflating: spectrogram_dataset/negative/bk1oHM5vebe9ZNtgyRq54UVOIQR2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bk1oHM5vebe9ZNtgyRq54UVOIQR2_1.png
#   inflating: spectrogram_dataset/negative/c8bac943-39b7-420f-9629-37d81d5e7b92.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c8bac943-39b7-420f-9629-37d81d5e7b92.png
#   inflating: spectrogram_dataset/negative/EZzVAG1b5ef8VopTkIROvVbYGml1_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._EZzVAG1b5ef8VopTkIROvVbYGml1_0.png
#   inflating: spectrogram_dataset/negative/c1c75ffb-98f4-49ad-b43d-90d3614979a9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c1c75ffb-98f4-49ad-b43d-90d3614979a9.png
#   inflating: spectrogram_dataset/negative/A7tcR4TNNfYhbtnLDTckg6yUVho1_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._A7tcR4TNNfYhbtnLDTckg6yUVho1_1.png
#   inflating: spectrogram_dataset/negative/f5cbf9d2-1d4b-4296-b85e-0cabca9e1d81.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f5cbf9d2-1d4b-4296-b85e-0cabca9e1d81.png
#   inflating: spectrogram_dataset/negative/f48df4bf-6e7f-48ab-8d74-8807f0fdc2db.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f48df4bf-6e7f-48ab-8d74-8807f0fdc2db.png
#   inflating: spectrogram_dataset/negative/eW3UMx8SACOoZft0ZOLZUIVaTFb2_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._eW3UMx8SACOoZft0ZOLZUIVaTFb2_1.png
#   inflating: spectrogram_dataset/negative/b050e291-ed8f-4f8f-a8f6-e8b92dfbda7f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b050e291-ed8f-4f8f-a8f6-e8b92dfbda7f.png
#   inflating: spectrogram_dataset/negative/e210e2b3-aaf0-44a2-81f1-b4bb8ff81c97.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._e210e2b3-aaf0-44a2-81f1-b4bb8ff81c97.png
#   inflating: spectrogram_dataset/negative/d1129121-8c1d-4fee-9422-c470911338f2.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d1129121-8c1d-4fee-9422-c470911338f2.png
#   inflating: spectrogram_dataset/negative/da025e66-3296-4e91-a91b-ba9774949b6c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._da025e66-3296-4e91-a91b-ba9774949b6c.png
#   inflating: spectrogram_dataset/negative/c879d91e-2626-4222-80cb-2c6891f7e87f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c879d91e-2626-4222-80cb-2c6891f7e87f.png
#   inflating: spectrogram_dataset/negative/a22ed907-2c12-4f92-86b7-ec6cf74a8386.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a22ed907-2c12-4f92-86b7-ec6cf74a8386.png
#   inflating: spectrogram_dataset/negative/aa716ab2-0bdb-4e5c-ad2d-4c59c9566e06.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._aa716ab2-0bdb-4e5c-ad2d-4c59c9566e06.png
#   inflating: spectrogram_dataset/negative/ab0eaab9-6e82-4c5a-94f1-0bd73c6821c1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ab0eaab9-6e82-4c5a-94f1-0bd73c6821c1.png
#   inflating: spectrogram_dataset/negative/bf990e0e-bbf6-4233-8578-e77aea74a3b1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bf990e0e-bbf6-4233-8578-e77aea74a3b1.png
#   inflating: spectrogram_dataset/negative/d6317e4f-69e0-4b7d-a16c-d59ff4dfd52c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d6317e4f-69e0-4b7d-a16c-d59ff4dfd52c.png
#   inflating: spectrogram_dataset/negative/b9ee5e0d-c28e-4e04-8b59-02aaf360e94d.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._b9ee5e0d-c28e-4e04-8b59-02aaf360e94d.png
#   inflating: spectrogram_dataset/negative/ee12514a-3ad4-41c8-8c27-a24310fd95f6.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._ee12514a-3ad4-41c8-8c27-a24310fd95f6.png
#   inflating: spectrogram_dataset/negative/AaGldp1blyVKOPpV1KVhsPhrmAg1_0.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._AaGldp1blyVKOPpV1KVhsPhrmAg1_0.png
#   inflating: spectrogram_dataset/negative/bc0b6411-5eb6-4bd8-a9ac-1d1278fd92b1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._bc0b6411-5eb6-4bd8-a9ac-1d1278fd92b1.png
#   inflating: spectrogram_dataset/negative/d005e56d-cf5d-44ca-bc7c-6b0fc2242c28.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d005e56d-cf5d-44ca-bc7c-6b0fc2242c28.png
#   inflating: spectrogram_dataset/negative/f358b0af-6fb5-43a5-854a-e95765d49311.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._f358b0af-6fb5-43a5-854a-e95765d49311.png
#   inflating: spectrogram_dataset/negative/AaGldp1blyVKOPpV1KVhsPhrmAg1_1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._AaGldp1blyVKOPpV1KVhsPhrmAg1_1.png
#   inflating: spectrogram_dataset/negative/efa1d3d1-b29a-4f81-a5f5-ab5fadb6be14.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._efa1d3d1-b29a-4f81-a5f5-ab5fadb6be14.png
#   inflating: spectrogram_dataset/negative/c2e033f0-5e2f-4793-be75-afa9ae7d3f8f.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c2e033f0-5e2f-4793-be75-afa9ae7d3f8f.png
#   inflating: spectrogram_dataset/negative/a884a410-b9a7-4cd3-afb3-9791dda44fa1.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._a884a410-b9a7-4cd3-afb3-9791dda44fa1.png
#   inflating: spectrogram_dataset/negative/d340e250-d01d-4a31-a43f-aa8490aec06c.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._d340e250-d01d-4a31-a43f-aa8490aec06c.png
#   inflating: spectrogram_dataset/negative/c5a17f64-5195-463f-bd20-6c22efb88be9.png
#   inflating: __MACOSX/spectrogram_dataset/negative/._c5a17f64-5195-463f-bd20-6c22efb88be9.png
# ...
#   inflating: spectrogram_dataset/augmented_positive/e18b869f-b152-4fbc-b160-ae7b4bdd695712441.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._e18b869f-b152-4fbc-b160-ae7b4bdd695712441.png
#   inflating: spectrogram_dataset/augmented_positive/814a5c9e-6174-4efa-a378-a990ac566ae263878.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._814a5c9e-6174-4efa-a378-a990ac566ae263878.png
#   inflating: spectrogram_dataset/augmented_positive/8adab84f-c5d1-4adb-bda4-b29b12a4cd1249329.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._8adab84f-c5d1-4adb-bda4-b29b12a4cd1249329.png
#   inflating: spectrogram_dataset/augmented_positive/14fb399a-c792-43e2-b852-0e776f8a34a524526.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._14fb399a-c792-43e2-b852-0e776f8a34a524526.png
#   inflating: spectrogram_dataset/augmented_positive/NVzhTN4CXebH2lQVFkBTyl6ue5h2_014436.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._NVzhTN4CXebH2lQVFkBTyl6ue5h2_014436.png
#   inflating: spectrogram_dataset/augmented_positive/0YCuLUeRDeVmOwglsjizHm6Rq5S2_151551.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._0YCuLUeRDeVmOwglsjizHm6Rq5S2_151551.png
#   inflating: spectrogram_dataset/augmented_positive/26d7e2c7-6614-4dfc-af30-acefde8a21a981771.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._26d7e2c7-6614-4dfc-af30-acefde8a21a981771.png
#   inflating: spectrogram_dataset/augmented_positive/ae5dcf74-bf11-47a3-b0d6-c668a0794d8a28057.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._ae5dcf74-bf11-47a3-b0d6-c668a0794d8a28057.png
#   inflating: spectrogram_dataset/augmented_positive/S4mqUrR1ryRwv4Ylz3eSf5pceo62_133915.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._S4mqUrR1ryRwv4Ylz3eSf5pceo62_133915.png
#   inflating: spectrogram_dataset/augmented_positive/c9175625-2740-4f50-8ef0-c1a37b9688b184886.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._c9175625-2740-4f50-8ef0-c1a37b9688b184886.png
#   inflating: spectrogram_dataset/augmented_positive/5aa37322-c3d3-4a00-990e-4a5ce265fbfe51074.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._5aa37322-c3d3-4a00-990e-4a5ce265fbfe51074.png
#   inflating: spectrogram_dataset/augmented_positive/oq0WLx6gAuM9yYU3fybYvV4OqLf1_141635.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._oq0WLx6gAuM9yYU3fybYvV4OqLf1_141635.png
#   inflating: spectrogram_dataset/augmented_positive/QY3z2ZqQVkSv9kwYHesCDBacjD53_049669.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._QY3z2ZqQVkSv9kwYHesCDBacjD53_049669.png
#   inflating: spectrogram_dataset/augmented_positive/af89b4c6-a942-4dbd-9efb-cc0ae79a9acf35526.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._af89b4c6-a942-4dbd-9efb-cc0ae79a9acf35526.png
#   inflating: spectrogram_dataset/augmented_positive/b997dae1-4c89-47d1-827d-39f358a2fbfa98871.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._b997dae1-4c89-47d1-827d-39f358a2fbfa98871.png
#   inflating: spectrogram_dataset/augmented_positive/YRiIODBG3RXPbDttwztMhsXg1rv2_122495.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._YRiIODBG3RXPbDttwztMhsXg1rv2_122495.png
#   inflating: spectrogram_dataset/augmented_positive/13bbc1cd-358b-4e90-9a35-31428809eb2a51984.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._13bbc1cd-358b-4e90-9a35-31428809eb2a51984.png
#   inflating: spectrogram_dataset/augmented_positive/YQzhlTCYjlgentYYTgVEDgNPapN2_199451.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._YQzhlTCYjlgentYYTgVEDgNPapN2_199451.png
#   inflating: spectrogram_dataset/augmented_positive/13bbc1cd-358b-4e90-9a35-31428809eb2a78523.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._13bbc1cd-358b-4e90-9a35-31428809eb2a78523.png
#   inflating: spectrogram_dataset/augmented_positive/EuEoeANAhadcy5vzBikn3LxlGKh1_194252.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._EuEoeANAhadcy5vzBikn3LxlGKh1_194252.png
#   inflating: spectrogram_dataset/augmented_positive/814a5c9e-6174-4efa-a378-a990ac566ae214010.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._814a5c9e-6174-4efa-a378-a990ac566ae214010.png
#   inflating: spectrogram_dataset/augmented_positive/uwf9NvukzahzfoHla4EJcxALtr13_180364.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._uwf9NvukzahzfoHla4EJcxALtr13_180364.png
#   inflating: spectrogram_dataset/augmented_positive/QY3z2ZqQVkSv9kwYHesCDBacjD53_163876.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._QY3z2ZqQVkSv9kwYHesCDBacjD53_163876.png
#   inflating: spectrogram_dataset/augmented_positive/S4mqUrR1ryRwv4Ylz3eSf5pceo62_169206.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._S4mqUrR1ryRwv4Ylz3eSf5pceo62_169206.png
#   inflating: spectrogram_dataset/augmented_positive/1e3c046d-82f7-445e-b6c3-06441f3da50652701.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._1e3c046d-82f7-445e-b6c3-06441f3da50652701.png
#   inflating: spectrogram_dataset/augmented_positive/YQzhlTCYjlgentYYTgVEDgNPapN2_175374.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._YQzhlTCYjlgentYYTgVEDgNPapN2_175374.png
#   inflating: spectrogram_dataset/augmented_positive/2NszBeEmnHP7VFg0lKGdWZ6RkiE3_176879.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._2NszBeEmnHP7VFg0lKGdWZ6RkiE3_176879.png
#   inflating: spectrogram_dataset/augmented_positive/lpohIzcDNEg3DR38ku43WHiCkC42_199775.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._lpohIzcDNEg3DR38ku43WHiCkC42_199775.png
#   inflating: spectrogram_dataset/augmented_positive/tDjXrO1dI4O35JJXPL3ihLvnAzl1_160602.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._tDjXrO1dI4O35JJXPL3ihLvnAzl1_160602.png
#   inflating: spectrogram_dataset/augmented_positive/8fc1ec0d-4d46-4a76-a833-68763de21df182822.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._8fc1ec0d-4d46-4a76-a833-68763de21df182822.png
#   inflating: spectrogram_dataset/augmented_positive/EuEoeANAhadcy5vzBikn3LxlGKh1_180031.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._EuEoeANAhadcy5vzBikn3LxlGKh1_180031.png
#   inflating: spectrogram_dataset/augmented_positive/HTdlMNy8RTfSi54eAZ5tExU3XAG2_054904.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._HTdlMNy8RTfSi54eAZ5tExU3XAG2_054904.png
#   inflating: spectrogram_dataset/augmented_positive/d5e9a1af-2571-40f7-99c7-77cfe71657c59196.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._d5e9a1af-2571-40f7-99c7-77cfe71657c59196.png
#   inflating: spectrogram_dataset/augmented_positive/a0bd7465-ae76-40cd-903b-3591ed9595db50286.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._a0bd7465-ae76-40cd-903b-3591ed9595db50286.png
#   inflating: spectrogram_dataset/augmented_positive/gwg5V9vEkMYvDqW38tY5b82qYoi2_024671.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._gwg5V9vEkMYvDqW38tY5b82qYoi2_024671.png
#   inflating: spectrogram_dataset/augmented_positive/ab8ecc44-d33a-4e85-8e31-28cfe827fd1761581.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._ab8ecc44-d33a-4e85-8e31-28cfe827fd1761581.png
#   inflating: spectrogram_dataset/augmented_positive/13bbc1cd-358b-4e90-9a35-31428809eb2a63498.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._13bbc1cd-358b-4e90-9a35-31428809eb2a63498.png
#   inflating: spectrogram_dataset/augmented_positive/14c7b709-ac4d-4aee-bdbc-ac51c11a497e98246.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._14c7b709-ac4d-4aee-bdbc-ac51c11a497e98246.png
#   inflating: spectrogram_dataset/augmented_positive/xgdd8l7OfrMOkvrskW5s6fxk3mg2_190558.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._xgdd8l7OfrMOkvrskW5s6fxk3mg2_190558.png
#   inflating: spectrogram_dataset/augmented_positive/0KSi2atlmsXNcGMfpDNzIjJSvC23_149215.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._0KSi2atlmsXNcGMfpDNzIjJSvC23_149215.png
#   inflating: spectrogram_dataset/augmented_positive/fdbabb79-c296-4b93-9e02-06b290916fe749884.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._fdbabb79-c296-4b93-9e02-06b290916fe749884.png
#   inflating: spectrogram_dataset/augmented_positive/NVzhTN4CXebH2lQVFkBTyl6ue5h2_027189.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._NVzhTN4CXebH2lQVFkBTyl6ue5h2_027189.png
#   inflating: spectrogram_dataset/augmented_positive/YQzhlTCYjlgentYYTgVEDgNPapN2_079017.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._YQzhlTCYjlgentYYTgVEDgNPapN2_079017.png
#   inflating: spectrogram_dataset/augmented_positive/SwraVh5j7SQ4Zz495sCUouvQdlC2_018987.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._SwraVh5j7SQ4Zz495sCUouvQdlC2_018987.png
#   inflating: spectrogram_dataset/augmented_positive/2NszBeEmnHP7VFg0lKGdWZ6RkiE3_117504.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._2NszBeEmnHP7VFg0lKGdWZ6RkiE3_117504.png
#   inflating: spectrogram_dataset/augmented_positive/HTdlMNy8RTfSi54eAZ5tExU3XAG2_068024.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._HTdlMNy8RTfSi54eAZ5tExU3XAG2_068024.png
#   inflating: spectrogram_dataset/augmented_positive/668c6e03-edc6-45aa-98d1-429fe5bd92fa90973.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._668c6e03-edc6-45aa-98d1-429fe5bd92fa90973.png
#   inflating: spectrogram_dataset/augmented_positive/CUCqq4q5SQa3fDkpraekej7fNza2_045077.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._CUCqq4q5SQa3fDkpraekej7fNza2_045077.png
#   inflating: spectrogram_dataset/augmented_positive/09126c08-5214-4723-94f1-7b654464eac060693.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._09126c08-5214-4723-94f1-7b654464eac060693.png
#   inflating: spectrogram_dataset/augmented_positive/0b0d7e10-8353-4124-a16b-bf96e405f63c13292.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._0b0d7e10-8353-4124-a16b-bf96e405f63c13292.png
#   inflating: spectrogram_dataset/augmented_positive/ac4ea2db-4fff-4a7f-a5fe-3a9ade2f102041023.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._ac4ea2db-4fff-4a7f-a5fe-3a9ade2f102041023.png
#   inflating: spectrogram_dataset/augmented_positive/Tvdak0zflIVWdvWsNj7l9Ur0k3m1_14525.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._Tvdak0zflIVWdvWsNj7l9Ur0k3m1_14525.png
#   inflating: spectrogram_dataset/augmented_positive/4RTWSyPKTdc7aRr4ocbrk5m153M2_169269.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._4RTWSyPKTdc7aRr4ocbrk5m153M2_169269.png
#   inflating: spectrogram_dataset/augmented_positive/e3bc1069-6c55-448f-8d73-8d6b8aaa715a14259.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._e3bc1069-6c55-448f-8d73-8d6b8aaa715a14259.png
#   inflating: spectrogram_dataset/augmented_positive/178f39e2-a261-4ec6-a8fb-3f89c3c795bb1002.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._178f39e2-a261-4ec6-a8fb-3f89c3c795bb1002.png
#   inflating: spectrogram_dataset/augmented_positive/1NQvmLMrJyTwrmbNwAm6wDT4wpz2_121761.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._1NQvmLMrJyTwrmbNwAm6wDT4wpz2_121761.png
#   inflating: spectrogram_dataset/augmented_positive/NVzhTN4CXebH2lQVFkBTyl6ue5h2_191617.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._NVzhTN4CXebH2lQVFkBTyl6ue5h2_191617.png
#   inflating: spectrogram_dataset/augmented_positive/2K7RhQsuLKQpUUo7DrE0IgCwM9x2_057050.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._2K7RhQsuLKQpUUo7DrE0IgCwM9x2_057050.png
#   inflating: spectrogram_dataset/augmented_positive/lpohIzcDNEg3DR38ku43WHiCkC42_179509.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._lpohIzcDNEg3DR38ku43WHiCkC42_179509.png
#   inflating: spectrogram_dataset/augmented_positive/foSqAW8uRvWn3SsriOdFCLpNKY13_055880.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._foSqAW8uRvWn3SsriOdFCLpNKY13_055880.png
#   inflating: spectrogram_dataset/augmented_positive/1a324acb-12f7-4eef-8e8c-0c71a47280e284864.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._1a324acb-12f7-4eef-8e8c-0c71a47280e284864.png
#   inflating: spectrogram_dataset/augmented_positive/0eba0c0a-5609-4777-903d-b1529279825036952.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._0eba0c0a-5609-4777-903d-b1529279825036952.png
#   inflating: spectrogram_dataset/augmented_positive/b997dae1-4c89-47d1-827d-39f358a2fbfa30056.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._b997dae1-4c89-47d1-827d-39f358a2fbfa30056.png
#   inflating: spectrogram_dataset/augmented_positive/rR7IyyhZigMCIvfd2q2cjaGAIXY2_04029.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._rR7IyyhZigMCIvfd2q2cjaGAIXY2_04029.png
#   inflating: spectrogram_dataset/augmented_positive/OaOT17qcMJhtsIymSrSJh12d4iE2_135013.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._OaOT17qcMJhtsIymSrSJh12d4iE2_135013.png
#   inflating: spectrogram_dataset/augmented_positive/03c1afa7-eee5-4c18-bd40-c4d91e6d320e6558.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._03c1afa7-eee5-4c18-bd40-c4d91e6d320e6558.png
#   inflating: spectrogram_dataset/augmented_positive/cf97b7f8-de05-47f8-8a3c-d3ec1672d25f85749.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._cf97b7f8-de05-47f8-8a3c-d3ec1672d25f85749.png
#   inflating: spectrogram_dataset/augmented_positive/2K7RhQsuLKQpUUo7DrE0IgCwM9x2_064317.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._2K7RhQsuLKQpUUo7DrE0IgCwM9x2_064317.png
#   inflating: spectrogram_dataset/augmented_positive/aa4877b2-4820-422b-affe-c3d31c1fc70a63894.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._aa4877b2-4820-422b-affe-c3d31c1fc70a63894.png
#   inflating: spectrogram_dataset/augmented_positive/uwf9NvukzahzfoHla4EJcxALtr13_054242.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._uwf9NvukzahzfoHla4EJcxALtr13_054242.png
#   inflating: spectrogram_dataset/augmented_positive/foSqAW8uRvWn3SsriOdFCLpNKY13_058630.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._foSqAW8uRvWn3SsriOdFCLpNKY13_058630.png
#   inflating: spectrogram_dataset/augmented_positive/dvRr97gwv7Y34YqaccErnWcYRY53_130529.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._dvRr97gwv7Y34YqaccErnWcYRY53_130529.png
#   inflating: spectrogram_dataset/augmented_positive/oq0WLx6gAuM9yYU3fybYvV4OqLf1_0263.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._oq0WLx6gAuM9yYU3fybYvV4OqLf1_0263.png
#   inflating: spectrogram_dataset/augmented_positive/9YfQ4fzK7VhEKsDvMyPUsWPFqhk2_149971.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._9YfQ4fzK7VhEKsDvMyPUsWPFqhk2_149971.png
#   inflating: spectrogram_dataset/augmented_positive/qAQjizOoayfb4mCauvOecItW37Y2_062983.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._qAQjizOoayfb4mCauvOecItW37Y2_062983.png
#   inflating: spectrogram_dataset/augmented_positive/FC4RKq4W8uRrjmin8n2BXC4SrnU2_081439.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._FC4RKq4W8uRrjmin8n2BXC4SrnU2_081439.png
#   inflating: spectrogram_dataset/augmented_positive/182246b0-9f77-4c40-976e-3c934261981960410.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._182246b0-9f77-4c40-976e-3c934261981960410.png
#   inflating: spectrogram_dataset/augmented_positive/14c7b709-ac4d-4aee-bdbc-ac51c11a497e10190.png
#   inflating: __MACOSX/spectrogram_dataset/augmented_positive/._14c7b709-ac4d-4aee-bdbc-ac51c11a497e10190.png

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNNLSTM(nn.Module):
    def __init__(self):
        super(CNNLSTM, self).__init__()

        # CNN for feature extraction
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16, momentum=0.01),  # Lower momentum for stable running stats
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32, momentum=0.01),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, momentum=0.01),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128, momentum=0.01),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256, momentum=0.01),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Calculate CNN output size (assuming 224x224 input)
        self.cnn_output_size = 256 * 7 * 7  # 12544

        # LSTM parameters
        self.lstm_hidden_size = 128
        self.lstm_num_layers = 2

        # Fully connected layer to transform CNN features to LSTM input
        self.fc_before_lstm = nn.Linear(self.cnn_output_size, self.lstm_hidden_size)

        # LSTM
        self.lstm = nn.LSTM(
            input_size=self.lstm_hidden_size,
            hidden_size=self.lstm_hidden_size,
            num_layers=self.lstm_num_layers,
            batch_first=True
        )

        # Final classifier
        self.fc = nn.Sequential(
            nn.Linear(self.lstm_hidden_size, 100),
            nn.ReLU(),
            nn.Linear(100, 1)
        )

    def forward(self, x):
        batch_size = x.size(0)

        # CNN feature extraction
        cnn_features = self.cnn(x)  # (batch_size, 256, 7, 7)
        cnn_features = cnn_features.view(batch_size, -1)  # (batch_size, 12544)

        # Prepare sequence for LSTM
        transformed_features = self.fc_before_lstm(cnn_features)  # (batch_size, lstm_hidden_size)
        lstm_input = transformed_features.unsqueeze(1)  # (batch_size, 1, lstm_hidden_size)

        # Initialize hidden state and cell state
        h0 = torch.zeros(self.lstm_num_layers, batch_size, self.lstm_hidden_size).to(x.device)
        c0 = torch.zeros(self.lstm_num_layers, batch_size, self.lstm_hidden_size).to(x.device)

        # LSTM
        lstm_output, _ = self.lstm(lstm_input, (h0, c0))  # lstm_output: (batch_size, 1, lstm_hidden_size)

        # Use the last output for classification
        last_output = lstm_output[:, -1, :]  # Take the last timestep output

        # Classification
        out = self.fc(last_output)  # (batch_size, 1)

        return out

# %% [markdown]
# # DataPipeline

# %%
class DataPipeline:
    """Processes datasets, including loading, splitting, and preparing for inference.

    This class provides methods for loading datasets, processing them for training,
    and preparing single instances for inference.

    Attributes:
        test_size (float): Proportion of the dataset to include in the test split.
        val_size (float): Proportion of the dataset to include for validation.
    """

    def __init__(self, test_size: float, val_size: float):
        """Initializes the DatasetProcessor.

        Args:
            data_path (str): Path to the dataset file.
            test_size (float): Proportion of the dataset to include in the test split.
        """
        self.test_size = test_size
        self.val_size = val_size

    def load_dataset(self) -> TensorDataset:
        """Loads the dataset from the specified file path into a DataFrame."""
        tensors = []
        labels = []

        for label_folder, label_value in zip(["positive", "negative", "augmented_positive"], [1, 0, 1]):
            spectrogram_folder = '/content/spectrogram_dataset'
            output_dir = os.path.join(spectrogram_folder, label_folder)

            for image_name in tqdm(os.listdir(output_dir)):
                image_path = os.path.join(output_dir, image_name)
                if(image_path[-4:] == '.png'):
                  image_tensor = self.image_to_tensor(image_path)

                  tensors.append(image_tensor)
                  labels.append(label_value)

        # Tensor of all features (N x D) - N is number of samples (377), D is feature dimension (3,224,224)
        X = torch.stack(tensors)
        # Tensor of all labels (N x 1) - 377x1
        y = torch.tensor(labels, dtype=torch.long)

        return TensorDataset(X, y)


    def image_to_tensor(self, image_path: str) -> torch.Tensor:
        """Converts a spectrogram image to a PyTorch tensor.

        Args:
            image_path (str): Path to the spectrogram image file.

        Returns:
            torch.Tensor: The PyTorch tensor representation of the image.
        """
        transform = transforms.Compose([
            transforms.Resize((224, 224)),  # Resize to ResNet18 input size
            transforms.ToTensor(),  # Convert image to tensor
        ])

        image = Image.open(image_path).convert("RGB") # Convert from RGBA to RGB
        tensor_image = transform(image)

        return tensor_image  # shape will be 3, 224, 224

    def create_dataloaders(self, batch_size, dataset_path = None, upsample = False) -> tuple[DataLoader, DataLoader, DataLoader]:
        """Splits the dataset into training and test sets.

        Args:
            batch_size (int): The batch size for the DataLoader.
            dataset_path (str | None): Path to the TensorDataset file.

        Returns:
            tuple: (train_df, test_df) - The training and testing DataFrames.
        """
        if dataset_path:
            print(f"Loading dataset from {dataset_path}")
            dataset = torch.load(dataset_path, weights_only=False)
        else:
            print("Processing and loading dataset")
            dataset = self.load_dataset()

        # Calculate sizes
        test_size = round(self.test_size * len(dataset))
        val_size = round(self.val_size * len(dataset))
        train_size = round(len(dataset) - test_size - val_size)  # Remaining for training

        # Perform split
        train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

        # Upsample positive class
        if upsample:
            print("Upsampling data")
            labels = [label.item() for _, label in train_dataset]
            train_counts = {}
            for label in labels:
                train_counts[label] = train_counts.get(label, 0) + 1
            # print(train_counts)

            weights = torch.where(torch.tensor(labels) == 0, 1 / train_counts[0], 1 / train_counts[1])
            # print(labels[:5], weights[:5])

            wr_sampler = WeightedRandomSampler(weights, int(len(train_dataset) * 1.5))

            train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=wr_sampler)

        else:
            print("No upsampling")
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        # Create DataLoaders
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        # Count labels in train_loader
        train_counts = {}
        for _, labels in train_loader:
            for label in labels:
                train_counts[label.item()] = train_counts.get(label.item(), 0) + 1

        print(train_counts)

        # Reduce memory footprint
        dataset, train_dataset, val_dataset, test_dataset = None, None, None, None

        return train_loader, val_loader, test_loader

# %% [markdown]
# # Model Handler

# %%
class ModelHandler:
    """Handles the model training, evaluation, and inference pipeline.

    Attributes:
        device (torch.device): The device on which the model is executed (e.g., 'cpu' or 'cuda').
        model_path: Path to where .pth models should be saved.
    """

    def __init__(
        self,
        model: nn.Module,
        model_path: str,
        optimizer: opt.Optimizer,
        loss_function: nn.Module,
        lr_scheduler: opt.lr_scheduler.LRScheduler,
    ):
        """Initializes the ModelHandler.

        Args:
            model (nn.Module): The machine learning model to be trained/evaluated.
            model_path (str | None): Path to the pre-trained model file (if available).
            optimizer (torch.optim.Optimizer): The optimizer used for training the model.
            loss_function (nn.Module): The loss function used for training the model.
            lr_scheduler (torch.optim.lr_scheduler.LRScheduler): The learning rate scheduler.

        Example Usage:
            model = CNNModel()
            optimizer = opt.Adam(model.parameters(), lr=0.001)
            loss_function = nn.BCEWithLogitsLoss()
            lr_scheduler = opt.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
            model_handler = ModelHandler(model, model_path, optimizer, loss_function, lr_scheduler)
        """
        self.model = model
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model_path = model_path
        self.optimizer = optimizer
        self.lr_scheduler = lr_scheduler
        self.loss_function = loss_function

    def train_step(self, dataloader) -> dict:
        """Used by self.train(). Trains the model for a single epoch.

        Args:
            dataloader (torch.utils.data.DataLoader): DataLoader for the training dataset.

        Returns:
            Dictionary of training information.
                "avg_loss_per_batch": Average loss per batch.
                "avg_acc_per_batch": Average accuracy per batch.
        """
        self.model.train()  # Set model to training mode
        avg_loss, acc = (
            0,
            0,
        )  # We will calculate the average loss and accuracy per batch
        for in_tensor, labels in dataloader:
            in_tensor, labels = in_tensor.to(self.device), labels.to(self.device)
            labels = labels.float().unsqueeze(1)  # Ensure correct shape for BCE loss

            logits = self.model(in_tensor)  # Feed input into model

            loss = self.loss_function(logits, labels)  # Calculate batch loss
            avg_loss += loss.item()  # Add to cumulative loss

            # Gradient descent
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            # Calculate batch accuracy and add it to cumulative accuracy
            prediction_classes = torch.round(torch.sigmoid(logits))
            batch_acc = torch.mean((prediction_classes == labels).float()).item()
            acc += batch_acc

        avg_loss /= len(dataloader)  # Calculate avg loss for epoch from cumulative loss
        acc /= len(
            dataloader
        )  # Calculate avg accuracy for epoch from cumulative accuracy
        train_results = {"avg_loss_per_batch": avg_loss, "avg_acc_per_batch": acc * 100}
        return train_results

    def val_step(self, dataloader) -> dict:
        """Used by self.train(). Evaluates the model on the validation dataset.

        Args:
            dataloader (torch.utils.data.DataLoader): DataLoader for the validation dataset.

        Returns:
            Dictionary of validation information.
                "avg_loss_per_batch": Average loss per batch.
                "avg_acc_per_batch": Average accuracy per batch.
        """

        self.model.eval()
        with torch.inference_mode():
            avg_loss, acc = 0, 0
            for in_tensor, labels in dataloader:
                in_tensor, labels = in_tensor.to(self.device), labels.to(self.device)
                labels = labels.float().unsqueeze(
                    1
                )  # Ensure correct shape for BCE loss

                logits = self.model(in_tensor)  # Feed input into model

                loss = self.loss_function(logits, labels)  # Calculate batch loss
                avg_loss += loss.item()  # Add to cumulative loss

                # Calculate batch accuracy and add it to cumulative accuracy
                prediction_classes = torch.round(torch.sigmoid(logits))
                batch_acc = torch.mean((prediction_classes == labels).float()).item()
                acc += batch_acc

            avg_loss /= len(
                dataloader
            )  # Calculate avg loss for each epoch from cumulative loss
            acc /= len(
                dataloader
            )  # Calculate avg accuracy for each epoch from cumulative accuracy
            valid_results = {
                "avg_loss_per_batch": avg_loss,
                "avg_acc_per_batch": acc * 100,
            }
            return valid_results

    def train(
        self, train_loader, val_loader, epochs: int, model_name: str
    ) -> tuple[dict, dict]:
        """Trains the model.

        Args:
            train_loader: DataLoader for the training datasets
            epochs (int): Number of training epochs.
            model_name (str): Name to save the trained model.

        Returns:
            Two dictionaries containing the following training and validation information:
                "epoch": List of epoch numbers.
                "loss": List of average loss per batch.
                "accuracy": List of average accuracy per
        """
        self.model.to(self.device)
        training_results = {"epoch": [], "loss": [], "accuracy": []}
        validation_results = {"epoch": [], "loss": [], "accuracy": []}

        for epoch in range(epochs):

            # Train the model
            training_data = self.train_step(train_loader)
            training_results["epoch"].append(epoch)
            training_results["loss"].append(training_data["avg_loss_per_batch"])
            training_results["accuracy"].append(training_data["avg_acc_per_batch"])

            # Check the validation loss after training
            validation_data = self.val_step(val_loader)
            validation_results["epoch"].append(epoch)
            validation_results["loss"].append(validation_data["avg_loss_per_batch"])
            validation_results["accuracy"].append(validation_data["avg_acc_per_batch"])

            # Adjust learning rate if necessary
            if self.lr_scheduler:
                # Some LR schedulers take validation loss as input, others will ignore it (I think)
                self.lr_scheduler.step(validation_data["avg_loss_per_batch"])

            print(f"{epoch}:")
            print(f"LR: {self.optimizer.param_groups[0]['lr']}")
            print(
                f"Loss - {training_data['avg_loss_per_batch']:.5f} | Accuracy - {training_data['avg_acc_per_batch']:.2f}%"
            )
            print(
                f"VLoss - {validation_data['avg_loss_per_batch']:.5f} | VAccuracy - {validation_data['avg_acc_per_batch']:.2f}%\n"
            )
        self.save_model(model_state_dict=self.model.state_dict(), model_name=model_name)
        return training_results, validation_results

    def validate(
        self, val_loader, hyperparams: dict, save_best: bool = True
    ) -> tuple[float, float]:
        """Validates the model on the validation dataset.

        Args:
            val_loader: DataLoader for the validation dataset.

        Returns:
            tuple: (validation accuracy, validation loss)
        """

        self.model.to(self.device)
        self.model.eval()

        val_losses_epoch, batch_sizes, accs = [], [], []
        best_acc = -1
        best_model_state = None  # Track the best model weights

        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val = X_val.to(self.device)
                y_val = y_val.to(self.device).float().unsqueeze(1)

                y_prediction_val = self.model(X_val)  # forward pass
                loss = self.loss_function(y_prediction_val, y_val)
                val_losses_epoch.append(loss.item())

                # Compute accuracy
                y_prediction_val = torch.sigmoid(
                    y_prediction_val
                )  # Convert logits to probabilities
                prediction_classes = (
                    y_prediction_val > 0.5
                ).float()  # Convert to binary 0/1

                acc = torch.mean((prediction_classes == y_val).float()).item()
                accs.append(acc)
                batch_sizes.append(X_val.shape[0])

        # Compute final validation loss and accuracy
        val_loss = np.mean(val_losses_epoch)
        val_acc = np.average(accs, weights=batch_sizes)  # Weighted average accuracy

        print(
            f"Validation accuracy: {val_acc*100:.2f}% | Validation loss: {val_loss:.4f}"
        )

        if save_best and val_acc > best_acc:
            best_acc = val_acc
            best_model_state = self.model.state_dict()

            # Create model filename using hyperparameters
            hyperparam_str = "_".join(
                f"{key}:{value}" for key, value in hyperparams.items()
            )
            model_filename = f"model_{hyperparam_str}_{time.time()}.pth"

            # Save the best model
            save_path = os.path.join(self.model_path, model_filename)
            torch.save(best_model_state, save_path)
            print(f"Best model saved at: {save_path}")
        return val_acc, val_loss

    def evaluate(self, test_loader) -> float:
        """Evaluates the model on the test dataset.

        Args:
            test_loader: DataLoader for the test dataset.
        """
        self.model.to(self.device)
        self.model.eval()
        batch_sizes, accs = [], []
        with torch.no_grad():
          for (
              X_test,
              y_test,
          ) in test_loader:
              X_test = X_test.to(self.device)
              y_test = y_test.to(self.device).float().unsqueeze(1)

              prediction = self.model(X_test)
              batch_sizes.append(X_test.shape[0])

              prediction = torch.round(torch.sigmoid(prediction))
              # prediction_classes = (
              #     prediction > 0.5
              # ).float()  # This converts to binary classes 0 and 1

              acc = torch.mean((prediction == y_test).float()).item()
              accs.append(acc)

        # Return average accuracy
        print(accs)
        return np.average(accs, weights=batch_sizes)

    def predict(self, spectrogram: torch.Tensor) -> int:
        """Performs inference on a single spectrogram.

        Args:
            spectrogram (torch.Tensor): Input spectrogram for inference.

        Returns:
            torch.Tensor: The predicted output from the model.
        """

        self.model.load_state_dict(
            torch.load(self.model_path, map_location=torch.device("cpu"))
        )
        self.model.to(self.device)
        self.model.eval()

        spectrogram = spectrogram.unsqueeze(0).to(self.device)

        with torch.no_grad():
            logits = self.model(spectrogram)

            probability = torch.sigmoid(logits)
            print(probability)

            prediction = (
                probability > 0.5
            ).float()  # Turn probability into binary classificaiton
        print("Performed prediction on image.")
        return prediction.item()

    def save_model(
        self, model_state_dict: collections.OrderedDict, model_name: str | None
    ) -> None:
        """Saves the model to the specified file path.

        Args:
            path (str): Path to save the model file.
        """
        path = self.model_path + "/" + model_name
        torch.save(model_state_dict, path)

    def load_model(self, path: str) -> None:
        """Loads a model from the specified file path.

        Args:
            path (str): Path to the model file.
        """
        self.model.load_state_dict(torch.load(path))
        self.model.to(self.device)
        self.model.eval()

# %% [markdown]
# # Dataset

# %%
datapipeline = DataPipeline(test_size=0.15, val_size=0.15)
train_loader, val_loader, test_loader = datapipeline.create_dataloaders(batch_size=8)
# Out:
# Processing and loading dataset
# 100%|██████████| 1944/1944 [00:22<00:00, 88.26it/s]
# 100%|██████████| 3109/3109 [00:36<00:00, 84.53it/s]
# 100%|██████████| 1164/1164 [00:12<00:00, 90.31it/s]
# No upsampling
# {0: 2174, 1: 2178}

# %% [markdown]
# # Training

# %%
# Instantiate the model
model = CNNLSTM()

# Define optimizer, loss function, and learning rate scheduler
optimizer = opt.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)  # SGD optimizer
# optimizer = opt.Adam(model.parameters(), lr=0.001)
loss_function = nn.BCEWithLogitsLoss()
lr_scheduler = opt.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# Define model save path
model_path = "/content/Models"

# Instantiate the model handler
model_handler = ModelHandler(
    model=model,
    model_path=model_path,
    optimizer=optimizer,
    loss_function=loss_function,
    lr_scheduler=lr_scheduler,
)

# Set training parameters
epochs = 15
model_name = "krish_cnn_lstm_hybrid.pth"

# Train the model
training_results, validation_results = model_handler.train(train_loader, val_loader, epochs, model_name)

# Evaluate on test set
test_accuracy = model_handler.evaluate(test_loader)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 0:
# LR: 0.001
# Loss - 0.69301 | Accuracy - 51.47%
# VLoss - 0.69265 | VAccuracy - 56.94%
#
# 1:
# LR: 0.001
# Loss - 0.69214 | Accuracy - 54.55%
# VLoss - 0.69138 | VAccuracy - 58.01%
#
# 2:
# LR: 0.001
# Loss - 0.69009 | Accuracy - 56.59%
# VLoss - 0.68750 | VAccuracy - 62.07%
#
# 3:
# LR: 0.001
# Loss - 0.68328 | Accuracy - 62.13%
# VLoss - 0.67453 | VAccuracy - 66.45%
#
# 4:
# LR: 0.001
# Loss - 0.65839 | Accuracy - 66.25%
# VLoss - 0.63050 | VAccuracy - 69.55%
#
# 5:
# LR: 0.001
# Loss - 0.60722 | Accuracy - 69.19%
# VLoss - 0.67141 | VAccuracy - 61.75%
#
# 6:
# LR: 0.001
# Loss - 0.53631 | Accuracy - 74.29%
# VLoss - 0.50451 | VAccuracy - 78.21%
#
# 7:
# LR: 0.001
# Loss - 0.49209 | Accuracy - 77.18%
# VLoss - 0.50888 | VAccuracy - 75.64%
#
# 8:
# LR: 0.001
# Loss - 0.47999 | Accuracy - 78.12%
# VLoss - 0.46150 | VAccuracy - 79.38%
#
# 9:
# LR: 0.001
# Loss - 0.46569 | Accuracy - 78.19%
# VLoss - 0.46188 | VAccuracy - 79.70%
#
# 10:
# LR: 0.001
# Loss - 0.44569 | Accuracy - 79.50%
# VLoss - 0.47008 | VAccuracy - 78.21%
#
# 11:
# LR: 0.001
# Loss - 0.43656 | Accuracy - 80.33%
# VLoss - 0.46602 | VAccuracy - 78.53%
#
# 12:
# LR: 0.001
# Loss - 0.42226 | Accuracy - 80.72%
# VLoss - 0.48140 | VAccuracy - 76.50%
#
# 13:
# LR: 0.001
# Loss - 0.41350 | Accuracy - 81.78%
# VLoss - 0.47737 | VAccuracy - 77.24%
#
# 14:
# LR: 0.001
# Loss - 0.39552 | Accuracy - 82.26%
# VLoss - 0.47732 | VAccuracy - 76.82%
#
# [1.0, 1.0, 0.75, 0.625, 0.875, 0.5, 0.875, 0.5, 0.875, 0.875, 0.5, 0.5, 0.5, 0.75, 0.875, 1.0, 0.875, 0.75, 0.625, 1.0, 0.75, 0.75, 0.75, 0.625, 0.875, 0.75, 0.875, 0.75, 0.75, 0.625, 0.875, 0.625, 0.75, 0.875, 0.5, 0.875, 1.0, 1.0, 1.0, 0.75, 0.75, 0.5, 1.0, 0.875, 0.625, 0.875, 0.625, 0.75, 0.75, 0.875, 0.75, 0.75, 0.75, 0.75, 0.75, 1.0, 0.75, 1.0, 0.75, 0.375, 0.5, 0.875, 0.875, 0.625, 0.75, 0.625, 0.75, 0.875, 0.625, 0.75, 0.75, 0.875, 0.875, 0.875, 0.5, 0.75, 0.75, 0.5, 0.875, 0.75, 1.0, 0.625, 0.75, 0.625, 1.0, 0.625, 0.5, 0.875, 0.875, 0.75, 0.875, 0.875, 0.875, 0.75, 0.875, 0.75, 0.75, 1.0, 0.875, 0.75, 0.75, 1.0, 0.875, 0.625, 1.0, 0.75, 0.625, 0.75, 0.75, 0.625, 0.5, 1.0, 0.625, 0.625, 0.5, 0.75, 0.5]
# Test Accuracy: 76.39%
