# %%
from data_processing.spectrogram_processor import SpectrogramProcessor

# %%
processor = SpectrogramProcessor("", "") #not passing the folders as that's not needed at this point

# %%
spectrogram_1 = processor.conv_to_spectrogram("087749f6-e253-464f-b576-e85f6ed62cae.wav") #load sample file into same directory
stft_1 = processor.apply_stft("087749f6-e253-464f-b576-e85f6ed62cae.wav")

# %%
processor.plot_spectrogram("Sample 1", processor.normalize_spectrogram(spectrogram_1)) #plot the spectrograms
processor.plot_spectrogram("Sample 1 with STFT", processor.normalize_spectrogram(stft_1))
